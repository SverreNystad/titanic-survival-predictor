# %% [markdown]
# # AutoViz EDA tool
# AutoViz is a Python library designed to automate data visualization, making it an excellent tool for quick and insightful exploratory data analysis (EDA) with minimal code. AutoViz can automatically generate various charts and graphs to help you understand your dataset better.
#
# ## Case notebook does not run
# If the notebook can not run due to some import version issues, create an virtual environment use that as the kernel for this notebook.
# ```bash
# python -m venv venv_autoviz
# ```
# Then use that for this notebook.

# %%
# %pip install autoviz
# Out:
# Requirement already satisfied: autoviz in /home/sverrnys/Dokumenter/personal_projects/titanic-survival-predictor/venv_autoviz/lib64/python3.12/site-packages (0.1.904)
# Requirement already satisfied: xlrd in /home/sverrnys/Dokumenter/personal_projects/titanic-survival-predictor/venv_autoviz/lib64/python3.12/site-packages (from autoviz) (2.0.1)
# Requirement already satisfied: wordcloud in /home/sverrnys/Dokumenter/personal_projects/titanic-survival-predictor/venv_autoviz/lib64/python3.12/site-packages (from autoviz) (1.9.3)
# Requirement already satisfied: emoji in /home/sverrnys/Dokumenter/personal_projects/titanic-survival-predictor/venv_autoviz/lib64/python3.12/site-packages (from autoviz) (2.12.1)
# Requirement already satisfied: pyamg in /home/sverrnys/Dokumenter/personal_projects/titanic-survival-predictor/venv_autoviz/lib64/python3.12/site-packages (from autoviz) (5.1.0)
# Requirement already satisfied: scikit-learn in /home/sverrnys/Dokumenter/personal_projects/titanic-survival-predictor/venv_autoviz/lib64/python3.12/site-packages (from autoviz) (1.4.2)
# Requirement already satisfied: statsmodels in /home/sverrnys/Dokumenter/personal_projects/titanic-survival-predictor/venv_autoviz/lib64/python3.12/site-packages (from autoviz) (0.14.2)
# Requirement already satisfied: nltk in /home/sverrnys/Dokumenter/personal_projects/titanic-survival-predictor/venv_autoviz/lib64/python3.12/site-packages (from autoviz) (3.8.1)
# Requirement already satisfied: textblob in /home/sverrnys/Dokumenter/personal_projects/titanic-survival-predictor/venv_autoviz/lib64/python3.12/site-packages (from autoviz) (0.18.0.post0)
# Collecting xgboost<1.7,>=0.82 (from autoviz)
#   Using cached xgboost-1.6.2-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Requirement already satisfied: fsspec>=0.8.3 in /home/sverrnys/Dokumenter/personal_projects/titanic-survival-predictor/venv_autoviz/lib64/python3.12/site-packages (from autoviz) (2024.5.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in /home/sverrnys/Dokumenter/personal_projects/titanic-survival-predictor/venv_autoviz/lib64/python3.12/site-packages (from autoviz) (4.11.0)
# Requirement already satisfied: pandas-dq>=1.29 in /home/sverrnys/Dokumenter/personal_projects/titanic-survival-predictor/venv_autoviz/lib64/python3.12/site-packages (from autoviz) (1.29)
# Requirement already satisfied: numpy>=1.24.0 in /home/sverrnys/Dokumenter/personal_projects/titanic-survival-predictor/venv_autoviz/lib64/python3.12/site-packages (from autoviz) (1.26.4)
# Requirement already satisfied: hvplot>=0.9.2 in /home/sverrnys/Dokumenter/personal_projects/titanic-survival-predictor/venv_autoviz/lib64/python3.12/site-packages (from autoviz) (0.10.0)
# Requirement already satisfied: holoviews>=1.16.0 in /home/sverrnys/Dokumenter/personal_projects/titanic-survival-predictor/venv_autoviz/lib64/python3.12/site-packages (from autoviz) (1.18.3)
# Requirement already satisfied: panel>=1.4.0 in /home/sverrnys/Dokumenter/personal_projects/titanic-survival-predictor/venv_autoviz/lib64/python3.12/site-packages (from autoviz) (1.4.2)
# Requirement already satisfied: pandas>=2.0 in /home/sverrnys/Dokumenter/personal_projects/titanic-survival-predictor/venv_autoviz/lib64/python3.12/site-packages (from autoviz) (2.2.2)
# Requirement already satisfied: matplotlib>3.7.4 in /home/sverrnys/Dokumenter/personal_projects/titanic-survival-predictor/venv_autoviz/lib64/python3.12/site-packages (from autoviz) (3.9.0)
# Requirement already satisfied: seaborn>0.12.2 in /home/sverrnys/Dokumenter/personal_projects/titanic-survival-predictor/venv_autoviz/lib64/python3.12/site-packages (from autoviz) (0.13.2)
# Requirement already satisfied: param<3.0,>=1.12.0 in /home/sverrnys/Dokumenter/personal_projects/titanic-survival-predictor/venv_autoviz/lib64/python3.12/site-packages (from holoviews>=1.16.0->autoviz) (2.1.0)
# Requirement already satisfied: pyviz-comms>=0.7.4 in /home/sverrnys/Dokumenter/personal_projects/titanic-survival-predictor/venv_autoviz/lib64/python3.12/site-packages (from holoviews>=1.16.0->autoviz) (3.0.2)
# Requirement already satisfied: colorcet in /home/sverrnys/Dokumenter/personal_projects/titanic-survival-predictor/venv_autoviz/lib64/python3.12/site-packages (from holoviews>=1.16.0->autoviz) (3.1.0)
# Requirement already satisfied: packaging in /home/sverrnys/Dokumenter/personal_projects/titanic-survival-predictor/venv_autoviz/lib64/python3.12/site-packages (from holoviews>=1.16.0->autoviz) (24.0)
# Requirement already satisfied: bokeh>=1.0.0 in /home/sverrnys/Dokumenter/personal_projects/titanic-survival-predictor/venv_autoviz/lib64/python3.12/site-packages (from hvplot>=0.9.2->autoviz) (3.4.1)
# Requirement already satisfied: contourpy>=1.0.1 in /home/sverrnys/Dokumenter/personal_projects/titanic-survival-predictor/venv_autoviz/lib64/python3.12/site-packages (from matplotlib>3.7.4->autoviz) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /home/sverrnys/Dokumenter/personal_projects/titanic-survival-predictor/venv_autoviz/lib64/python3.12/site-packages (from matplotlib>3.7.4->autoviz) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/sverrnys/Dokumenter/personal_projects/titanic-survival-predictor/venv_autoviz/lib64/python3.12/site-packages (from matplotlib>3.7.4->autoviz) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/sverrnys/Dokumenter/personal_projects/titanic-survival-predictor/venv_autoviz/lib64/python3.12/site-packages (from matplotlib>3.7.4->autoviz) (1.4.5)
# Requirement already satisfied: pillow>=8 in /home/sverrnys/Dokumenter/personal_projects/titanic-survival-predictor/venv_autoviz/lib64/python3.12/site-packages (from matplotlib>3.7.4->autoviz) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/sverrnys/Dokumenter/personal_projects/titanic-survival-predictor/venv_autoviz/lib64/python3.12/site-packages (from matplotlib>3.7.4->autoviz) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/sverrnys/Dokumenter/personal_projects/titanic-survival-predictor/venv_autoviz/lib64/python3.12/site-packages (from matplotlib>3.7.4->autoviz) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/sverrnys/Dokumenter/personal_projects/titanic-survival-predictor/venv_autoviz/lib64/python3.12/site-packages (from pandas>=2.0->autoviz) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/sverrnys/Dokumenter/personal_projects/titanic-survival-predictor/venv_autoviz/lib64/python3.12/site-packages (from pandas>=2.0->autoviz) (2024.1)
# Requirement already satisfied: xyzservices>=2021.09.1 in /home/sverrnys/Dokumenter/personal_projects/titanic-survival-predictor/venv_autoviz/lib64/python3.12/site-packages (from panel>=1.4.0->autoviz) (2024.4.0)
# Requirement already satisfied: markdown in /home/sverrnys/Dokumenter/personal_projects/titanic-survival-predictor/venv_autoviz/lib64/python3.12/site-packages (from panel>=1.4.0->autoviz) (3.6)
# Requirement already satisfied: markdown-it-py in /home/sverrnys/Dokumenter/personal_projects/titanic-survival-predictor/venv_autoviz/lib64/python3.12/site-packages (from panel>=1.4.0->autoviz) (3.0.0)
# Requirement already satisfied: linkify-it-py in /home/sverrnys/Dokumenter/personal_projects/titanic-survival-predictor/venv_autoviz/lib64/python3.12/site-packages (from panel>=1.4.0->autoviz) (2.0.3)
# Requirement already satisfied: mdit-py-plugins in /home/sverrnys/Dokumenter/personal_projects/titanic-survival-predictor/venv_autoviz/lib64/python3.12/site-packages (from panel>=1.4.0->autoviz) (0.4.1)
# Requirement already satisfied: requests in /home/sverrnys/Dokumenter/personal_projects/titanic-survival-predictor/venv_autoviz/lib64/python3.12/site-packages (from panel>=1.4.0->autoviz) (2.32.0)
# Requirement already satisfied: tqdm>=4.48.0 in /home/sverrnys/Dokumenter/personal_projects/titanic-survival-predictor/venv_autoviz/lib64/python3.12/site-packages (from panel>=1.4.0->autoviz) (4.66.4)
# Requirement already satisfied: bleach in /home/sverrnys/Dokumenter/personal_projects/titanic-survival-predictor/venv_autoviz/lib64/python3.12/site-packages (from panel>=1.4.0->autoviz) (6.1.0)
# Requirement already satisfied: scipy>=1.6.0 in /home/sverrnys/Dokumenter/personal_projects/titanic-survival-predictor/venv_autoviz/lib64/python3.12/site-packages (from scikit-learn->autoviz) (1.13.0)
# Requirement already satisfied: joblib>=1.2.0 in /home/sverrnys/Dokumenter/personal_projects/titanic-survival-predictor/venv_autoviz/lib64/python3.12/site-packages (from scikit-learn->autoviz) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/sverrnys/Dokumenter/personal_projects/titanic-survival-predictor/venv_autoviz/lib64/python3.12/site-packages (from scikit-learn->autoviz) (3.5.0)
# Requirement already satisfied: click in /home/sverrnys/Dokumenter/personal_projects/titanic-survival-predictor/venv_autoviz/lib64/python3.12/site-packages (from nltk->autoviz) (8.1.7)
# Requirement already satisfied: regex>=2021.8.3 in /home/sverrnys/Dokumenter/personal_projects/titanic-survival-predictor/venv_autoviz/lib64/python3.12/site-packages (from nltk->autoviz) (2024.5.15)
# Requirement already satisfied: patsy>=0.5.6 in /home/sverrnys/Dokumenter/personal_projects/titanic-survival-predictor/venv_autoviz/lib64/python3.12/site-packages (from statsmodels->autoviz) (0.5.6)
# Requirement already satisfied: Jinja2>=2.9 in /home/sverrnys/Dokumenter/personal_projects/titanic-survival-predictor/venv_autoviz/lib64/python3.12/site-packages (from bokeh>=1.0.0->hvplot>=0.9.2->autoviz) (3.1.4)
# Requirement already satisfied: PyYAML>=3.10 in /home/sverrnys/Dokumenter/personal_projects/titanic-survival-predictor/venv_autoviz/lib64/python3.12/site-packages (from bokeh>=1.0.0->hvplot>=0.9.2->autoviz) (6.0.1)
# Requirement already satisfied: tornado>=6.2 in /home/sverrnys/Dokumenter/personal_projects/titanic-survival-predictor/venv_autoviz/lib64/python3.12/site-packages (from bokeh>=1.0.0->hvplot>=0.9.2->autoviz) (6.4)
# Requirement already satisfied: six in /home/sverrnys/Dokumenter/personal_projects/titanic-survival-predictor/venv_autoviz/lib64/python3.12/site-packages (from patsy>=0.5.6->statsmodels->autoviz) (1.16.0)
# Requirement already satisfied: webencodings in /home/sverrnys/Dokumenter/personal_projects/titanic-survival-predictor/venv_autoviz/lib64/python3.12/site-packages (from bleach->panel>=1.4.0->autoviz) (0.5.1)
# Requirement already satisfied: uc-micro-py in /home/sverrnys/Dokumenter/personal_projects/titanic-survival-predictor/venv_autoviz/lib64/python3.12/site-packages (from linkify-it-py->panel>=1.4.0->autoviz) (1.0.3)
# Requirement already satisfied: mdurl~=0.1 in /home/sverrnys/Dokumenter/personal_projects/titanic-survival-predictor/venv_autoviz/lib64/python3.12/site-packages (from markdown-it-py->panel>=1.4.0->autoviz) (0.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/sverrnys/Dokumenter/personal_projects/titanic-survival-predictor/venv_autoviz/lib64/python3.12/site-packages (from requests->panel>=1.4.0->autoviz) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/sverrnys/Dokumenter/personal_projects/titanic-survival-predictor/venv_autoviz/lib64/python3.12/site-packages (from requests->panel>=1.4.0->autoviz) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/sverrnys/Dokumenter/personal_projects/titanic-survival-predictor/venv_autoviz/lib64/python3.12/site-packages (from requests->panel>=1.4.0->autoviz) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/sverrnys/Dokumenter/personal_projects/titanic-survival-predictor/venv_autoviz/lib64/python3.12/site-packages (from requests->panel>=1.4.0->autoviz) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/sverrnys/Dokumenter/personal_projects/titanic-survival-predictor/venv_autoviz/lib64/python3.12/site-packages (from Jinja2>=2.9->bokeh>=1.0.0->hvplot>=0.9.2->autoviz) (2.1.5)
# Using cached xgboost-1.6.2-py3-none-manylinux2014_x86_64.whl (255.9 MB)
# Installing collected packages: xgboost
#   Attempting uninstall: xgboost
#     Found existing installation: xgboost 2.0.3
#     Uninstalling xgboost-2.0.3:
#       Successfully uninstalled xgboost-2.0.3
# Successfully installed xgboost-1.6.2
#
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import sys
import os
import pandas as pd
from autoviz import AutoViz_Class
# %matplotlib inline

# Get the current working directory
current_working_directory = os.getcwd()

# Go up one level from the current working directory
parent_directory = os.path.join(current_working_directory, '..')

# Add the parent directory to sys.path
sys.path.append(parent_directory)

os.getcwd()

from src.config import REPORT_PATH, FIGURE_PATH, TARGET_FEATURE
from src.data.data_loader import create_data_loader
# Out:
# Imported v0.1.904. Please call AutoViz in this sequence:
#     AV = AutoViz_Class()
#     %matplotlib inline
#     dfte = AV.AutoViz(filename, sep=',', depVar='', dfte=None, header=0, verbose=1, lowess=False,
#                chart_format='svg',max_rows_analyzed=150000,max_cols_analyzed=30, save_plot_dir=None)

# %% [markdown]
# ## Load data

# %%
x, y = create_data_loader().load_raw_data()
training_data = pd.concat([x, y], axis=1)

# %% [markdown]
# ## Generate report

# %%
AV = AutoViz_Class()


custom_plot_dir = FIGURE_PATH

dft = AV.AutoViz(
    "", # Empty string for filename to signal that we are passing a dataframe
    sep=",",
    depVar=TARGET_FEATURE,
    dfte=training_data,
    verbose=2,
    lowess=False,
    chart_format="html",
    max_rows_analyzed=150000,
    max_cols_analyzed=training_data.shape[1],
    save_plot_dir=custom_plot_dir
)
# Out:
# Shape of your Data Set loaded: (891, 12)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
#   Printing up to 30 columns (max) in each category:
#     Numeric Columns : ['Age', 'Fare']
#     Integer-Categorical Columns: ['Pclass', 'SibSp', 'Parch']
#     String-Categorical Columns: ['Embarked']
#     Factor-Categorical Columns: []
#     String-Boolean Columns: ['Sex']
#     Numeric-Boolean Columns: []
#     Discrete String Columns: ['Ticket', 'Cabin']
#     NLP text Columns: ['Name']
#     Date Time Columns: []
#     ID Columns: ['PassengerId']
#     Columns that will not be considered in modeling: []
#     11 Predictors classified...
#         1 variable(s) removed since they were ID or low-information variables
#         List of variables removed: ['PassengerId']
#
# ################ Binary_Classification problem #####################
#    Columns to delete:
# '   []'
#    Boolean variables %s
# "   ['Sex']"
#    Categorical variables %s
# "   ['Embarked', 'Pclass', 'SibSp', 'Parch', 'Sex']"
#    Continuous variables %s
# "   ['Age', 'Fare']"
#    Discrete string variables %s
# "   ['Name', 'Ticket', 'Cabin']"
#    Date and time variables %s
# '   []'
#    ID variables %s
# "   ['PassengerId']"
#    Target variable %s
# '   Survived'
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="c372c9ae-c921-4c11-a6da-29a00a99b780" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"3228147f-f555-44e5-8392-e454a94063b9":{"version":"3.4.1","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"p1002"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"p1003","attributes":{"plot_id":"p1002","comm_id":"f5d2fc64dc5c493793d6d9ae158f1762","client_comm_id":"440449226cc0431fb79bcba4dd631e16"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"copy_to_clipboard1","properties":[{"name":"fill","kind":"A ...
#   var render_items = [{"docid":"3228147f-f555-44e5-8392-e454a94063b9","roots":{"p1002":"c372c9ae-c921-4c11-a6da-29a00a99b780"},"root_ids":["p1002"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# WARNING:param.Scatter: Chart elements should only be supplied a single kdim
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# Saving scatterplots in HTML format
#   0%|          | 0/2 [00:00<?, ?it/s]
# WARNING:param.Scatter: Chart elements should only be supplied a single kdim
# WARNING:param.Scatter: Chart elements should only be supplied a single kdim
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='p1017', ...)
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# Saving pair_scatters in HTML format
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='p1216', ...)
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# Saving distplots_cats in HTML format
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# Saving distplots_nums in HTML format
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# KDE plot is erroring due to problems with DynamicMaps. Hence it is skipped
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# Saving violinplots in HTML format
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# Saving heatmaps in HTML format
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# Saving cat_var_plots in HTML format
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='p2600', ...)
# Time to run AutoViz (in seconds) = 6
