# %% [markdown]
# # D-Tale EDA tool
# D-Tale is an EDA tool that provides a web-based interface to explore your data. It integrates with Jupyter Notebooks and supports various features like filtering, sorting, and generating plots.
#
#
# ## Case notebook does not run
# If the notebook can not run due to some import version issues, create an virtual environment use that as the kernel for this notebook.
# ```bash
# python -m venv venv_dtale
# ```
# Then use that for this notebook.

# %%
# %pip install dtale
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting dtale
#   Downloading dtale-3.12.0-py2.py3-none-any.whl.metadata (16 kB)
# Collecting dash-colorscales (from dtale)
#   Downloading dash_colorscales-0.0.4.tar.gz (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 kB 2.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting dash-daq (from dtale)
#   Downloading dash_daq-0.5.0.tar.gz (642 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 642.7/642.7 kB 5.2 MB/s eta 0:00:00m eta 0:00:010:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting Flask-Compress (from dtale)
#   Downloading Flask_Compress-1.15-py3-none-any.whl.metadata (8.4 kB)
# Collecting future>=0.14.0 (from dtale)
#   Downloading future-1.0.0-py3-none-any.whl.metadata (4.0 kB)
# Collecting kaleido (from dtale)
#   Downloading kaleido-0.2.1-py2.py3-none-manylinux1_x86_64.whl.metadata (15 kB)
# Collecting missingno (from dtale)
#   Downloading missingno-0.5.2-py3-none-any.whl.metadata (639 bytes)
# Requirement already satisfied: pandas in /home/sverrnys/.local/lib/python3.12/site-packages (from dtale) (2.2.2)
# Collecting squarify (from dtale)
#   Downloading squarify-0.4.3-py3-none-any.whl.metadata (540 bytes)
# Collecting strsimpy (from dtale)
#   Downloading strsimpy-0.2.1-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: six in /usr/lib/python3.12/site-packages (from dtale) (1.16.0)
# Collecting xlrd (from dtale)
#   Downloading xlrd-2.0.1-py2.py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: beautifulsoup4!=4.13.0b2 in /usr/lib/python3.12/site-packages (from dtale) (4.12.3)
# Requirement already satisfied: certifi in /usr/lib/python3.12/site-packages (from dtale) (2023.5.7)
# Collecting flask-ngrok (from dtale)
#   Downloading flask_ngrok-0.0.25-py3-none-any.whl.metadata (1.8 kB)
# Collecting lz4 (from dtale)
#   Downloading lz4-4.3.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.7 kB)
# Requirement already satisfied: cycler in /home/sverrnys/.local/lib/python3.12/site-packages (from dtale) (0.12.1)
# Collecting dash-bootstrap-components<=1.3.1 (from dtale)
#   Downloading dash_bootstrap_components-1.3.1-py3-none-any.whl.metadata (5.2 kB)
# Collecting dash (from dtale)
#   Downloading dash-2.17.0-py3-none-any.whl.metadata (10 kB)
# Collecting seaborn (from dtale)
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting werkzeug (from dtale)
#   Downloading werkzeug-3.0.3-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: scikit-learn in /home/sverrnys/.local/lib/python3.12/site-packages (from dtale) (1.4.2)
# Collecting statsmodels (from dtale)
#   Downloading statsmodels-0.14.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.2 kB)
# Collecting networkx (from dtale)
#   Using cached networkx-3.3-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: numpy in /home/sverrnys/.local/lib/python3.12/site-packages (from dtale) (1.26.4)
# Collecting openpyxl!=3.2.0b1 (from dtale)
#   Downloading openpyxl-3.1.2-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting xarray (from dtale)
#   Downloading xarray-2024.5.0-py3-none-any.whl.metadata (11 kB)
# Collecting et-xmlfile (from dtale)
#   Downloading et_xmlfile-1.1.0-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: plotly in /home/sverrnys/.local/lib/python3.12/site-packages (from dtale) (5.22.0)
# Collecting Flask<2.3 (from dtale)
#   Downloading Flask-2.2.5-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: requests in /usr/lib/python3.12/site-packages (from dtale) (2.31.0)
# Collecting itsdangerous (from dtale)
#   Downloading itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: contourpy in /home/sverrnys/.local/lib/python3.12/site-packages (from dtale) (1.2.1)
# Requirement already satisfied: matplotlib in /home/sverrnys/.local/lib/python3.12/site-packages (from dtale) (3.9.0)
# Requirement already satisfied: scipy!=1.12.0rc1 in /home/sverrnys/.local/lib/python3.12/site-packages (from dtale) (1.13.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/lib/python3.12/site-packages (from beautifulsoup4!=4.13.0b2->dtale) (2.5)
# Collecting dash-html-components==2.0.0 (from dash->dtale)
#   Downloading dash_html_components-2.0.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting dash-core-components==2.0.0 (from dash->dtale)
#   Downloading dash_core_components-2.0.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting dash-table==5.0.0 (from dash->dtale)
#   Downloading dash_table-5.0.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting importlib-metadata (from dash->dtale)
#   Downloading importlib_metadata-7.1.0-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: typing-extensions>=4.1.1 in /usr/lib/python3.12/site-packages (from dash->dtale) (4.9.0)
# Collecting retrying (from dash->dtale)
#   Downloading retrying-1.3.4-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: nest-asyncio in /home/sverrnys/.local/lib/python3.12/site-packages (from dash->dtale) (1.6.0)
# Requirement already satisfied: setuptools in /usr/lib/python3.12/site-packages (from dash->dtale) (69.0.3)
# Requirement already satisfied: Jinja2>=3.0 in /home/sverrnys/.local/lib/python3.12/site-packages (from Flask<2.3->dtale) (3.1.4)
# Requirement already satisfied: click>=8.0 in /usr/lib/python3.12/site-packages (from Flask<2.3->dtale) (8.1.7)
# Requirement already satisfied: tenacity>=6.2.0 in /home/sverrnys/.local/lib/python3.12/site-packages (from plotly->dtale) (8.3.0)
# Requirement already satisfied: packaging in /usr/lib/python3.12/site-packages (from plotly->dtale) (23.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/sverrnys/.local/lib/python3.12/site-packages (from werkzeug->dtale) (2.1.5)
# Collecting brotli (from Flask-Compress->dtale)
#   Downloading Brotli-1.1.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.5 kB)
# Collecting zstandard (from Flask-Compress->dtale)
#   Downloading zstandard-0.22.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.9 kB)
# Requirement already satisfied: fonttools>=4.22.0 in /home/sverrnys/.local/lib/python3.12/site-packages (from matplotlib->dtale) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/sverrnys/.local/lib/python3.12/site-packages (from matplotlib->dtale) (1.4.5)
# Requirement already satisfied: pillow>=8 in /home/sverrnys/.local/lib/python3.12/site-packages (from matplotlib->dtale) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/sverrnys/.local/lib/python3.12/site-packages (from matplotlib->dtale) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/lib/python3.12/site-packages (from matplotlib->dtale) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/sverrnys/.local/lib/python3.12/site-packages (from pandas->dtale) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/sverrnys/.local/lib/python3.12/site-packages (from pandas->dtale) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/lib/python3.12/site-packages (from requests->dtale) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3.12/site-packages (from requests->dtale) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/lib/python3.12/site-packages (from requests->dtale) (1.26.18)
# Requirement already satisfied: joblib>=1.2.0 in /home/sverrnys/.local/lib/python3.12/site-packages (from scikit-learn->dtale) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/sverrnys/.local/lib/python3.12/site-packages (from scikit-learn->dtale) (3.5.0)
# Collecting patsy>=0.5.6 (from statsmodels->dtale)
#   Downloading patsy-0.5.6-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting zipp>=0.5 (from importlib-metadata->dash->dtale)
#   Downloading zipp-3.18.2-py3-none-any.whl.metadata (3.5 kB)
# Downloading dtale-3.12.0-py2.py3-none-any.whl (14.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.3/14.3 MB 8.5 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading dash_bootstrap_components-1.3.1-py3-none-any.whl (219 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 219.7/219.7 kB 6.9 MB/s eta 0:00:00
# Downloading dash-2.17.0-py3-none-any.whl (7.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 10.2 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading dash_core_components-2.0.0-py3-none-any.whl (3.8 kB)
# Downloading dash_html_components-2.0.0-py3-none-any.whl (4.1 kB)
# Downloading dash_table-5.0.0-py3-none-any.whl (3.9 kB)
# Downloading Flask-2.2.5-py3-none-any.whl (101 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.8/101.8 kB 4.7 MB/s eta 0:00:00
# Downloading future-1.0.0-py3-none-any.whl (491 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.3/491.3 kB 9.5 MB/s eta 0:00:0013.7 MB/s eta 0:00:01
# Downloading itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Downloading openpyxl-3.1.2-py2.py3-none-any.whl (249 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.0/250.0 kB 7.6 MB/s eta 0:00:00
# Downloading werkzeug-3.0.3-py3-none-any.whl (227 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.3/227.3 kB 6.7 MB/s eta 0:00:00
# Downloading et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Downloading Flask_Compress-1.15-py3-none-any.whl (8.6 kB)
# Downloading flask_ngrok-0.0.25-py3-none-any.whl (3.1 kB)
# Downloading kaleido-0.2.1-py2.py3-none-manylinux1_x86_64.whl (79.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 10.3 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading lz4-4.3.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 10.9 MB/s eta 0:00:00m eta 0:00:010:01:01
# Downloading missingno-0.5.2-py3-none-any.whl (8.7 kB)
# Using cached networkx-3.3-py3-none-any.whl (1.7 MB)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 7.3 MB/s eta 0:00:0013.3 MB/s eta 0:00:01
# Downloading squarify-0.4.3-py3-none-any.whl (4.3 kB)
# Downloading statsmodels-0.14.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 11.4 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading strsimpy-0.2.1-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.9/45.9 kB 1.3 MB/s eta 0:00:00
# Downloading xarray-2024.5.0-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 10.5 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# Downloading xlrd-2.0.1-py2.py3-none-any.whl (96 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.5/96.5 kB 4.5 MB/s eta 0:00:00
# Downloading patsy-0.5.6-py2.py3-none-any.whl (233 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.9/233.9 kB 7.7 MB/s eta 0:00:00
# Downloading Brotli-1.1.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 10.9 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading importlib_metadata-7.1.0-py3-none-any.whl (24 kB)
# Downloading retrying-1.3.4-py3-none-any.whl (11 kB)
# Downloading zstandard-0.22.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 10.6 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading zipp-3.18.2-py3-none-any.whl (8.3 kB)
# Building wheels for collected packages: dash-colorscales, dash-daq
#   Building wheel for dash-colorscales (pyproject.toml) ... done
#   Created wheel for dash-colorscales: filename=dash_colorscales-0.0.4-py3-none-any.whl size=62814 sha256=6086c140314335580dec2573e001fe7af7ffba9a2a75a64d459f533bc0552f29
#   Stored in directory: /home/sverrnys/.cache/pip/wheels/84/23/44/63e5ef837d475b972c17c0a841473421c954069fdd7ba062ad
#   Building wheel for dash-daq (pyproject.toml) ... done
#   Created wheel for dash-daq: filename=dash_daq-0.5.0-py3-none-any.whl size=668593 sha256=28d967f37f3c9fddfebf0700024e120c2c55986cf20ba4f2865cc46e50e06b09
#   Stored in directory: /home/sverrnys/.cache/pip/wheels/40/89/1a/4435006b003f97da22dbcad819d26f957dad9d54a1678876fd
# Successfully built dash-colorscales dash-daq
# Installing collected packages: strsimpy, squarify, kaleido, dash-table, dash-html-components, dash-core-components, dash-colorscales, brotli, zstandard, zipp, xlrd, werkzeug, retrying, patsy, networkx, lz4, itsdangerous, future, et-xmlfile, openpyxl, importlib-metadata, Flask, xarray, statsmodels, seaborn, flask-ngrok, Flask-Compress, dash, missingno, dash-daq, dash-bootstrap-components, dtale
# Successfully installed Flask-2.2.5 Flask-Compress-1.15 brotli-1.1.0 dash-2.17.0 dash-bootstrap-components-1.3.1 dash-colorscales-0.0.4 dash-core-components-2.0.0 dash-daq-0.5.0 dash-html-components-2.0.0 dash-table-5.0.0 dtale-3.12.0 et-xmlfile-1.1.0 flask-ngrok-0.0.25 future-1.0.0 importlib-metadata-7.1.0 itsdangerous-2.2.0 kaleido-0.2.1 lz4-4.3.3 missingno-0.5.2 networkx-3.3 openpyxl-3.1.2 patsy-0.5.6 retrying-1.3.4 seaborn-0.13.2 squarify-0.4.3 statsmodels-0.14.2 strsimpy-0.2.1 werkzeug-3.0.3 xarray-2024.5.0 xlrd-2.0.1 zipp-3.18.2 zstandard-0.22.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import sys
import os
import pandas as pd
import dtale

# Get the current working directory
current_working_directory = os.getcwd()

# Go up one level from the current working directory
parent_directory = os.path.join(current_working_directory, '..')

# Add the parent directory to sys.path
sys.path.append(parent_directory)

os.getcwd()

from src.data.data_loader import create_data_loader

# %% [markdown]
# ## Load data

# %%
x, y = create_data_loader().load_raw_data()
training_data = pd.concat([x, y], axis=1)

# %% [markdown]
# ## Generate Report

# %%
# Start D-Tale session
d_tale = dtale.show(training_data)
d_tale.open_browser()
d_tale.notebook()
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://fedora:40000/dtale/iframe/1"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
